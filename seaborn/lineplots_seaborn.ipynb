# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('part-00000-dac123ca-8acd-4f0c-b541-f5a5ed4bf12c-c000.snappy (1).parquet', engine='pyarrow')

# %%
df["date"] = pd.to_datetime(df["date"])
df = df.set_index('date')

# %%
df
# Out:
#                 open      high       low     close       volume    market_cap  \
# date
# 2022-05-01  37713.27  38627.86  37585.79  38469.09  27002760110  731986764312
# 2022-04-30  38605.86  38771.21  37697.94  37714.88  23895713731  717596901509
# 2022-04-29  39768.62  39887.27  38235.54  38609.82  30882994649  734589762490
# 2022-04-28  39241.43  40269.47  38941.42  39773.83  33903704907  756698317682
# 2022-04-27  38120.30  39397.92  37997.31  39241.12  30981015184  746531438329
# ...              ...       ...       ...       ...          ...           ...
# 2022-05-06  36573.18  36624.36  35482.13  36040.92  37795577489  685953792236
# 2022-05-05  39695.75  39789.28  35856.52  36575.14  43106256317  696088266356
# 2022-05-04  37748.01  39902.95  37732.06  39698.37  36754404490  755491473700
# 2022-05-03  38528.11  38629.99  37585.62  37750.45  27326943244  718385701943
# 2022-05-02  38472.19  39074.97  38156.56  38529.33  32922642426  733170725791
#
# ...

# %%
sns.lineplot(data = df['close'])
# Out:
# <AxesSubplot:xlabel='date', ylabel='close'>

# %%
# size of image
plt.figure(figsize=(14,6))

# Add title
plt.title("Bitcoin Price")

# The graph
sns.lineplot(data = df[['close', 'high']])
plt.show()

# %%
# multiple plots
# size of image
plt.figure(figsize=(14,6))
# Add title
plt.title("Bitcoin Price")
# The graph
sns.lineplot(data = df['low'], label = 'low')
sns.lineplot(data = df['high'], label = 'high')
plt.show()
